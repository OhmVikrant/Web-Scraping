# %% [markdown]
# # Charts and rating from IMDb
#
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %%
from bs4 import BeautifulSoup
from terminaltables import DoubleTable
from colorclass import Color
import requests

# %%
def select():
    options = {
        1: ('Top movies' , 'top'),
        2: ('Most Popular Movies' , 'moviemeter'),
        3: ('Top English Movies' , 'top-english-movies'),
        4: ('Top TV Shows' , 'toptv'),
        5: ('Most Popular TV Shows' , 'tvmeter'),
        6: ('Low Rated Movies', 'bottom'),
        7: ('Top Box Office collection', 'boxoffice')
    }

    for i,option in enumerate(options,1):
        print("{}) {}".format(i,options[option][0]))

    choice = int(input('\nEnter your choice: '))
    while(choice<1 or choice>len(options)):
        print('Wrong choice')
        choice = int(input('\nEnter your choice: '))

    print()
    return options[choice][1]


def get_data(option):
    res = requests.get('http://m.imdb.com/chart/'+option)
    soup = BeautifulSoup(res.text, 'lxml')
    card_list = soup.find_all('span',{'class':'media-body media-vertical-align'})
    result = []
    for card in card_list:
        try:
            name = card.find('h4').text.replace("\n"," ").lstrip("0123456789.- ")
        except: 
            pass
        try:
            rating = card.find('p').text.strip()
        except:
            pass

        result.append((name,rating))

    return result


def make_table(result):
    table_data = [['S.No', 'Name', 'Rating']]

    for s_no,res in enumerate(result,1):
        row = []
        row.extend((Color('{autoyellow}' + str(s_no) + '.' + '{/autoyellow}'),
                        Color('{autogreen}' + res[0] + '{/autogreen}'),
                        Color('{autoyellow}' + res[1] + '{/autoyellow}')))
        table_data.append(row)

    table_instance = DoubleTable(table_data)
    table_instance.inner_row_border = True

    print(table_instance.table)
    print()

# %%
def main():
    option = select()
    data = get_data(option)
    make_table(data)

if __name__ == '__main__':
    main()
# Out:
# 1) Top movies
# 2) Most Popular Movies
# 3) Top English Movies
# 4) Top TV Shows
# 5) Most Popular TV Shows
# 6) Low Rated Movies
# 7) Top Box Office collection
#
# Enter your choice: 6
#
# ╔══════╦═══════════════════════════════════════════════════════╦════════╗
# ║ S.No ║ Name                                                  ║ Rating ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 1.   ║ Disaster Movie (2008)                                 ║ 2.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 2.   ║ Superbabies: Baby Geniuses 2 (2004)                   ║ 2.1    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 3.   ║ Manos: The Hands of Fate (1966)                       ║ 2.1    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 4.   ║ Code Name: K.O.Z. (2015)                              ║ 2.2    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 5.   ║ Birdemic: Shock and Terror (2010)                     ║ 2.2    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 6.   ║ Saving Christmas (2014)                               ║ 2.2    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 7.   ║ The Hottie & the Nottie (2008)                        ║ 2.3    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 8.   ║ House of the Dead (2003)                              ║ 2.3    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 9.   ║ Pledge This! (2006)                                   ║ 2.4    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 10.  ║ Son of the Mask (2005)                                ║ 2.4    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 11.  ║ Epic Movie (2007)                                     ║ 2.5    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 12.  ║ Turks in Space (2006)                                 ║ 2.5    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 13.  ║ Alone in the Dark (2005)                              ║ 2.6    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 14.  ║ From Justin to Kelly (2003)                           ║ 2.6    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 15.  ║ Battlefield Earth (2000)                              ║ 2.6    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 16.  ║ Going Overboard (1989)                                ║ 2.6    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 17.  ║ Dragonball Evolution (2009)                           ║ 2.6    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 18.  ║ Daniel the Wizard (2004)                              ║ 2.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 19.  ║ Gigli (2003)                                          ║ 2.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 20.  ║ Glitter (2001)                                        ║ 2.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 21.  ║ Race 3 (2018)                                         ║ 2.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 22.  ║ Meet the Spartans (2008)                              ║ 2.9    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 23.  ║ Date Movie (2006)                                     ║ 2.9    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 24.  ║ Baby Geniuses (1999)                                  ║ 2.9    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 25.  ║ Cats (2019)                                           ║ 3.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 26.  ║ Who's Your Caddy? (2007)                              ║ 3.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 27.  ║ Enes Batur (2018)                                     ║ 3.1    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 28.  ║ Hobgoblins (1988)                                     ║ 3.1    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 29.  ║ Jaws: The Revenge (1987)                              ║ 3.1    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 30.  ║ BloodRayne (2005)                                     ║ 3.1    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 31.  ║ The Human Centipede III (Final Sequence) (2015)       ║ 3.1    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 32.  ║ Troll 2 (1990)                                        ║ 3.2    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 33.  ║ Left Behind (2014)                                    ║ 3.2    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 34.  ║ Tees Maar Khan (2010)                                 ║ 3.3    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 35.  ║ Kazaam (1996)                                         ║ 3.3    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 36.  ║ Gunday (2014)                                         ║ 3.3    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 37.  ║ Rollerball (2002)                                     ║ 3.4    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 38.  ║ Jack and Jill (2011)                                  ║ 3.4    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 39.  ║ Steel (1997)                                          ║ 3.4    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 40.  ║ Santa Claus Conquers the Martians (1964)              ║ 3.4    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 41.  ║ Catwoman (2004)                                       ║ 3.4    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 42.  ║ The Emoji Movie (2017)                                ║ 3.4    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 43.  ║ Slender Man (2018)                                    ║ 3.5    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 44.  ║ The Starving Games (2013)                             ║ 3.5    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 45.  ║ Vampires Suck (2010)                                  ║ 3.5    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 46.  ║ Bratz (2007)                                          ║ 3.5    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 47.  ║ Daddy Day Camp (2007)                                 ║ 3.5    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 48.  ║ Barb Wire (1996)                                      ║ 3.5    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 49.  ║ The Open House (2018)                                 ║ 3.5    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 50.  ║ Ninjas: High Noon at Mega Mountain (1998)             ║ 3.6    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 51.  ║ Far Cry (2008)                                        ║ 3.6    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 52.  ║ Dumb and Dumberer: When Harry Met Lloyd (2003)        ║ 3.6    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 53.  ║ Texas Chainsaw Massacre: The Next Generation (1995)   ║ 3.6    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 54.  ║ Scary Movie 5 (2013)                                  ║ 3.6    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 55.  ║ The Master of Disguise (2002)                         ║ 3.6    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 56.  ║ Hercules in New York (1970)                           ║ 3.6    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 57.  ║ Spice World (1997)                                    ║ 3.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 58.  ║ Spy Kids 4-D: All the Time in the World (2011)        ║ 3.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 59.  ║ Crossroads (2002)                                     ║ 3.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 60.  ║ The Adventures of Sharkboy and Lavagirl 3-D (2005)    ║ 3.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 61.  ║ Feardotcom (2002)                                     ║ 3.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 62.  ║ The Room (2003)                                       ║ 3.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 63.  ║ Bucky Larson: Born to Be a Star (2011)                ║ 3.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 64.  ║ Student of the Year 2 (2019)                          ║ 3.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 65.  ║ The NeverEnding Story III (1994)                      ║ 3.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 66.  ║ Captain America (1990)                                ║ 3.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 67.  ║ Fifty Shades of Black (2016)                          ║ 3.7    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 68.  ║ Police Academy: Mission to Moscow (1994)              ║ 3.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 69.  ║ Batman & Robin (1997)                                 ║ 3.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 70.  ║ Dragon Wars: D-War (2007)                             ║ 3.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 71.  ║ Jaws 3-D (1983)                                       ║ 3.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 72.  ║ The Wicker Man (2006)                                 ║ 3.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 73.  ║ Mortal Kombat: Annihilation (1997)                    ║ 3.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 74.  ║ Dungeons & Dragons (2000)                             ║ 3.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 75.  ║ I Know Who Killed Me (2007)                           ║ 3.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 76.  ║ Superman IV: The Quest for Peace (1987)               ║ 3.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 77.  ║ The Fog (2005)                                        ║ 3.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 78.  ║ Piranha 3DD (2012)                                    ║ 3.8    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 79.  ║ The Flintstones in Viva Rock Vegas (2000)             ║ 3.9    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 80.  ║ Mac and Me (1988)                                     ║ 3.9    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 81.  ║ The Love Guru (2008)                                  ║ 3.9    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 82.  ║ Street Fighter: The Legend of Chun-Li (2009)          ║ 3.9    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 83.  ║ Teen Wolf Too (1987)                                  ║ 3.9    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 84.  ║ In the Name of the King: A Dungeon Siege Tale (2007)  ║ 3.9    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 85.  ║ Stan Helsing (2009)                                   ║ 3.9    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 86.  ║ The Human Centipede II (Full Sequence) (2011)         ║ 3.9    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 87.  ║ Dance Flick (2009)                                    ║ 3.9    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 88.  ║ The Avengers (1998)                                   ║ 4.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 89.  ║ Speed 2: Cruise Control (1997)                        ║ 4.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 90.  ║ S. Darko (2009)                                       ║ 4.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 91.  ║ Swept Away (2002)                                     ║ 4.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 92.  ║ Ballistic: Ecks vs. Sever (2002)                      ║ 4.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 93.  ║ The Adventures of Pluto Nash (2002)                   ║ 4.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 94.  ║ The Hungover Games (2014)                             ║ 4.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 95.  ║ Holmes & Watson (2018)                                ║ 4.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 96.  ║ Recep Ivedik 5 (2017)                                 ║ 4.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 97.  ║ Exorcist II: The Heretic (1977)                       ║ 4.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 98.  ║ Beverly Hills Chihuahua (2008)                        ║ 4.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 99.  ║ The Cat in the Hat (2003)                             ║ 4.0    ║
# ╠══════╬═══════════════════════════════════════════════════════╬════════╣
# ║ 100. ║ Street Fighter (1994)                                 ║ 4.0    ║
# ╚══════╩═══════════════════════════════════════════════════════╩════════╝

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
